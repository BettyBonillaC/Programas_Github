# %% [markdown]
# # Figure 6

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
datosfinales08_0=np.load('datosF_MBBG_nobs_005_28junio2024.npy')

# %%
datosfinales08_1=np.load('datosF_MBBG_nobs_015_28junio2024.npy')

# %%
datosfinales08_2=np.load('datosF_MBBG_nobs_05_28junio2024.npy')

# %%
datosfinales08_3=np.load('datosF_MBBG_nobs_1_28junio2024.npy')

# %%
datosfinales08_4=np.load('datosF_MBBG_nobs_5_28junio2024.npy')

# %%
a=0.8
Vobs=0.005
V0=0.5
s=0
b00=(a-(s**2)/2)/np.log(V0/Vobs)
print('s=0 beta_lim_0=',b00)
s=0.025
b0=(a-(s**2)/2)/np.log(V0/Vobs)
print('s= 0.025 beta_lim=',b0)
print('s_max=',np.sqrt(1.6))
s=0.1
b0_m=(a-(s**2)/2)/np.log(V0/Vobs)
print('s=0.1 beta_lim_r=',b0_m)
s=0.5
b0_m2=(a-(s**2)/2)/np.log(V0/Vobs)
print('s=0.5 beta_lim=',b0_m2)
s=0.8
b0_m3=(a-(s**2)/2)/np.log(V0/Vobs)
print('s=0.8 beta_lim=',b0_m3)
s=1.
b0_m4=(a-(s**2)/2)/np.log(V0/Vobs)
print('s=1. beta_lim=',b0_m4)
s=1.2
b0_m5=(a-(s**2)/2)/np.log(V0/Vobs)
print('s=1.2 beta_lim=',b0_m5)
# Out:
# s=0 beta_lim_0= 0.17371779276130073
# s= 0.025 beta_lim= 0.17364993424850333
# s_max= 1.2649110640673518
# s=0.1 beta_lim_r= 0.1726320565565426
# s=0.5 beta_lim= 0.14657438764234748
# s=0.8 beta_lim= 0.10423067565678043
# s=1. beta_lim= 0.06514417228548777
# s=1.2 beta_lim= 0.017371779276130088

# %%
print(datosfinales08_0[10,6,7])
# Out:
# 0.015588338833317283

# %%
print(datosfinales08_0[0,21,7],datosfinales08_0[0,21,8])
print(datosfinales08_0[1,23,7],datosfinales08_0[1,23,8])
print(datosfinales08_0[2,26,7],datosfinales08_0[2,26,8])
print(datosfinales08_0[5,28,7],datosfinales08_0[5,28,8])
print(datosfinales08_0[8,22,7],datosfinales08_0[8,22,8])
print(datosfinales08_0[9,15,7],datosfinales08_0[9,15,8])
print(datosfinales08_0[10,6,7],datosfinales08_0[10,6,8])
# Out:
# 0.17034927244307277 0.7993657198046235
# 0.16179863394237604 0.6921862901761199
# 0.16714152113034653 0.630022247299119
# 0.14375435705862435 0.5295277334831126
# 0.09989475322678068 0.5584392195707543
# 0.06333996818145507 0.6232661952440661
# 0.015588338833317283 0.6985984506487669

# %% [markdown]
# # Figura 6A
# ## Vobs=0.005

# %%
fig,ax=plt.subplots()
ax.plot(datosfinales08_0[0,:,7],datosfinales08_0[0,:,8], c="black",marker='o') #s=0
ax.plot(datosfinales08_0[1,:,7],datosfinales08_0[1,:,8],c = "blue",marker='o') #s=0.025
ax.plot(datosfinales08_0[2,:,7],datosfinales08_0[2,:,8],c = "red",marker='o')  #s=0.1
#ax.plot(datosfinales08_0[3,:,7],datosfinales08_0[3,:,8],c = "gray",marker='o') #s=0.2
#ax.plot(datosfinales08_0[4,:,7],datosfinales08_0[4,:,8],c = "gray",marker='o') #s=0.4
ax.plot(datosfinales08_0[5,:,7],datosfinales08_0[5,:,8],c = "green",marker='o') #s=0.5
#ax.plot(datosfinales08_0[6,:,7],datosfinales08_0[6,:,8],c = "gray",marker='o') #s=0.6
#ax.plot(datosfinales08_0[7,:,7],datosfinales08_0[7,:,8],c = "gray",marker='o') # s=0.7
ax.plot(datosfinales08_0[8,:,7],datosfinales08_0[8,:,8],c = "yellow",marker='o') #s=0.8
ax.plot(datosfinales08_0[9,:,7],datosfinales08_0[9,:,8],c = "brown",marker='o') #s=1.0
ax.plot(datosfinales08_0[10,:,7],datosfinales08_0[10,:,8],c = "cyan",marker='o') #s=1.2

#ax.axvline(x=b00, ymin=0., ymax=1,color='black')
#ax.axvline(x=b0, ymin=0., ymax=1,color='blue')
#ax.axvline(x=b0_m, ymin=0., ymax=1,color='red')
#ax.axvline(x=b0_m2, ymin=0., ymax=1,color='green')
#ax.axvline(x=b0_m3, ymin=0., ymax=1,color='yellow')
#ax.axvline(x=b0_m4, ymin=0., ymax=1,color='brown')
#ax.axvline(x=b0_m5, ymin=0., ymax=1,color='cyan')
#ax.scatter(datosfinales08_0[0,21,7],datosfinales08_0[0,21,8],marker='o',c='white',edgecolors = "black",s=200)
#ax.scatter(datosfinales08_0[1,23,7],datosfinales08_0[1,23,8],marker='o',c='white',edgecolors = "blue",s=200)
#ax.scatter(datosfinales08_0[2,26,7],datosfinales08_0[2,26,8],marker='o',c='white',edgecolors = "red",s=200)
#ax.scatter(datosfinales08_0[5,28,7],datosfinales08_0[5,28,8],marker='o',c='white',edgecolors = "green",s=200)
#ax.scatter(datosfinales08_0[8,22,7],datosfinales08_0[8,22,8],marker='o',c='white',edgecolors = "yellow",s=200)
#ax.scatter(datosfinales08_0[9,15,7],datosfinales08_0[9,15,8],marker='o',c='white',edgecolors = "brown",s=200)
#ax.scatter(datosfinales08_0[10,6,7],datosfinales08_0[10,6,8],marker='o',c='white',edgecolors = "cyan",s=200)
ax.scatter(datosfinales08_0[0,21,7],datosfinales08_0[0,21,8],marker='s',c="black",s=100)
ax.scatter(datosfinales08_0[1,23,7],datosfinales08_0[1,23,8],marker='s',c="blue",s=100)
ax.scatter(datosfinales08_0[2,26,7],datosfinales08_0[2,26,8],marker='s',c="red",s=100)
ax.scatter(datosfinales08_0[5,28,7],datosfinales08_0[5,28,8],marker='s',c= "green",s=100)
ax.scatter(datosfinales08_0[8,22,7],datosfinales08_0[8,22,8],marker='s',c= "yellow",s=100)
ax.scatter(datosfinales08_0[9,15,7],datosfinales08_0[9,15,8],marker='s',c= "brown",s=100)
ax.scatter(datosfinales08_0[10,6,7],datosfinales08_0[10,6,8],marker='s',c="cyan",s=100)

ax.legend([    '$\sigma=0.000$','$\sigma=0.025$', 
            '$\sigma=0.100$', '$\sigma=0.500$',
            '$\sigma=0.800$', '$\sigma=1.000$',
            '$\sigma=1.200$', 
           '($\\beta_T=0.17$, $\\sigma_T=0.000$)','($\\beta_T=0.16$, $\\sigma_T=0.025$)',
           '($\\beta_T=0.16$, $\\sigma_T=0.100$)','($\\beta_T=0.14$, $\\sigma_T=0.500$)',
            '($\\beta_T=0.09$, $\\sigma_T=0.800$)','($\\beta_T=0.06$, $\\sigma_T=1.000$)',
          '($\\beta_T=0.01$, $\\sigma_T=1.200$)'], bbox_to_anchor = (1.1, 0.81))
ax.set_xlabel('$\hat{\\beta}_d$   $(days^{-1})$')
ax.set_ylabel('$\hat{\\alpha}_d$  $(days^{-1})$')
ax.set_xlim(0,0.6)
ax.set_ylim(0.4,0.85)
# Out:
# (0.4, 0.85)

# %%
fig.savefig('F6_A_Vobs005F.jpg')

# %%
a=0.8
Vobs=0.01
V0=0.5
s=0
b00=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim_0=',b00)
s=0.025
b0=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0)
print('s_max=',np.sqrt(1.6))
s=0.1
b0_m=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim_r=',b0_m)
s=0.5
b0_m2=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m2)
s=1.
b0_m3=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m3)
s=1.1
b0_m4=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m4)
s=1.2
b0_m5=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m5)
# Out:
# beta_lim_0= 0.20449777490826518
# beta_lim= 0.20441789296494162
# s_max= 1.2649110640673518
# beta_lim_r= 0.20321966381508852
# beta_lim= 0.17254499757884875
# beta_lim= 0.07668666559059945
# beta_lim= 0.04984633263388962
# beta_lim= 0.020449777490826535

# %%
print(datosfinales08_1[6,6,7])
# Out:
# 0.026752376150862026

# %% [markdown]
# # Figura 6B
# ## Vobs=0.05

# %%
a=0.8
Vobs=0.05
V0=0.5
s=0
b00=(a-(s**2)/2)/np.log(V0/Vobs)
print('s=0 beta_lim_0=',b00)
s=0.025
b0=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0)
print('s_max=',np.sqrt(1.6))
s=0.1
b0_m=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim_r=',b0_m)
s=0.5
b0_m2=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m2)
s=0.8
b0_m3=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m3)
s=1.0
b0_m4=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m4)
s=1.2
b0_m5=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m5)
# Out:
# s=0 beta_lim_0= 0.34743558552260145
# beta_lim= 0.34729986849700667
# s_max= 1.2649110640673518
# beta_lim_r= 0.3452641131130852
# beta_lim= 0.29314877528469496
# beta_lim= 0.20846135131356086
# beta_lim= 0.13028834457097555
# beta_lim= 0.034743558552260176

# %%
print(datosfinales08_2[10,9,7])
# Out:
# 0.02757967276886984

# %%
print(datosfinales08_2[0,43,7],datosfinales08_2[0,43,8])
print(datosfinales08_2[1,48,7],datosfinales08_2[1,48,8])
print(datosfinales08_2[2,53,7],datosfinales08_2[2,53,8])
print(datosfinales08_2[5,52,7],datosfinales08_2[5,52,8])
print(datosfinales08_2[8,39,7],datosfinales08_2[8,39,8])
print(datosfinales08_2[9,27,7],datosfinales08_2[9,27,8])
print(datosfinales08_2[10,9,7],datosfinales08_2[10,9,8])
# Out:
# 0.34711968975817414 0.7978833832408743
# 0.3413756201738019 0.7022651196522345
# 0.33402390117248854 0.6211324700717877
# 0.28857097339471144 0.5811647861841106
# 0.20083568061537665 0.6143540684182435
# 0.12394834186600692 0.6545798232613042
# 0.02757967276886984 0.7220938330248688

# %%
fig,ax=plt.subplots()
ax.plot(datosfinales08_2[0,:,7],datosfinales08_2[0,:,8], c="black",marker='o')
ax.plot(datosfinales08_2[1,:,7],datosfinales08_2[1,:,8],c = "blue",marker='o')
ax.plot(datosfinales08_2[2,:,7],datosfinales08_2[2,:,8],c = "red",marker='o')
ax.plot(datosfinales08_2[5,:,7],datosfinales08_2[5,:,8],c = "green",marker='o')
ax.plot(datosfinales08_2[8,:,7],datosfinales08_2[8,:,8],c = "yellow",marker='o')
ax.plot(datosfinales08_2[9,:,7],datosfinales08_2[9,:,8],c = "brown",marker='o')
ax.plot(datosfinales08_2[10,:,7],datosfinales08_2[10,:,8],c = "cyan",marker='o')
#ax.axvline(x=b00, ymin=0., ymax=1,color='black')
#ax.axvline(x=b0, ymin=0., ymax=1,color='blue')
#ax.axvline(x=b0_m, ymin=0., ymax=1,color='red')
#ax.axvline(x=b0_m2, ymin=0., ymax=1,color='green')
#ax.axvline(x=b0_m3, ymin=0., ymax=1,color='yellow')
#ax.axvline(x=b0_m4, ymin=0., ymax=1,color='brown')
#ax.axvline(x=b0_m5, ymin=0., ymax=1,color='cyan')
ax.scatter(datosfinales08_2[0,43,7],datosfinales08_2[0,43,8],marker='s',c="black",s=100)
ax.scatter(datosfinales08_2[1,48,7],datosfinales08_2[1,48,8],marker='s',c= "blue",s=100)
ax.scatter(datosfinales08_2[2,53,7],datosfinales08_2[2,53,8],marker='s',c= "red",s=100)
ax.scatter(datosfinales08_2[5,52,7],datosfinales08_2[5,52,8],marker='s',c= "green",s=100)
ax.scatter(datosfinales08_2[8,39,7],datosfinales08_2[8,39,8],marker='s',c= "yellow",s=100)
ax.scatter(datosfinales08_2[9,27,7],datosfinales08_2[9,27,8],marker='s',c="brown",s=100)
ax.scatter(datosfinales08_2[10,9,7],datosfinales08_2[10,9,8],marker='s',c= "cyan",s=100)
ax.legend([    '$\sigma=0.000$','$\sigma=0.025$', 
            '$\sigma=0.100$', '$\sigma=0.500$',
            '$\sigma=0.800$', '$\sigma=1.000$',
            '$\sigma=1.200$', 
           '($\\beta_T=0.34$, $\\sigma_T=0.000$)','($\\beta_T=0.34$, $\\sigma_T=0.025$)',
           '($\\beta_T=0.33$, $\\sigma_T=0.100$)','($\\beta_T=0.28$, $\\sigma_T=0.500$)',
            '($\\beta_T=0.20$, $\\sigma_T=0.800$)','($\\beta_T=0.12$, $\\sigma_T=1.000$)',
          '($\\beta_T=0.02$, $\\sigma_T=1.200$)'], bbox_to_anchor = (1.3, 0.75))

#plt.title('$\\alpha=0.8(days^{-1})$, $V_{obs}=0.1 (cm^3)$, $V_0=0.5 (cm^3)$')
#plt.text(.1,.794,'a=0.8')
ax.set_xlabel('$\hat{\\beta}_d$   $(days^{-1})$')
ax.set_ylabel('$\hat{\\alpha}_d$  $(days^{-1})$')
ax.set_xlim(0,0.6)
#ax.set_ylim(0.4,1.2)
ax.set_ylim(0.4,0.85)
# Out:
# (0.4, 0.85)

# %%
fig.savefig('F6_B_Vobs05F.jpg')

# %% [markdown]
# # Figura 6C
# ## Vobs=0.1

# %%
a=0.8
Vobs=0.1
V0=0.5
s=0
b00=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim_0=',b00)
s=0.025
b0=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0)
print('s_max=',np.sqrt(1.6))
s=0.1
b0_m=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim_r=',b0_m)
s=0.5
b0_m2=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m2)
s=0.8
b0_m3=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m3)
s=1.
b0_m4=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m4)
s=1.2
b0_m5=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m5)
# Out:
# beta_lim_0= 0.4970679476476895
# beta_lim= 0.49687378048063957
# s_max= 1.2649110640673518
# beta_lim_r= 0.49396127297489145
# beta_lim= 0.419401080827738
# beta_lim= 0.2982407685886137
# beta_lim= 0.1864004803678836
# beta_lim= 0.04970679476476899

# %%
print(datosfinales08_3[0,61,7])
# Out:
# 0.4908329836441049

# %%
print(datosfinales08_3[0,61,7],datosfinales08_3[0,61,8])
print(datosfinales08_3[1,69,7],datosfinales08_3[1,69,8])
print(datosfinales08_3[2,74,7],datosfinales08_3[2,74,8])
print(datosfinales08_3[5,67,7],datosfinales08_3[5,67,8])
print(datosfinales08_3[8,53,7],datosfinales08_3[8,53,8])
print(datosfinales08_3[9,36,7],datosfinales08_3[9,36,8])
print(datosfinales08_3[10,12,7],datosfinales08_3[10,12,8])
# Out:
# 0.4908329836441049 0.7959795674871288
# 0.49246209446172434 0.7055817180238947
# 0.4886888604974685 0.6527553750153643
# 0.4100919828048664 0.63309720383755
# 0.2947280837403566 0.6427135793174589
# 0.17812348759032356 0.6805897149319985
# 0.046000360968153825 0.7466376423293973

# %%
fig,ax=plt.subplots()
ax.plot(datosfinales08_3[0,:,7],datosfinales08_3[0,:,8], c="black",marker='o')
ax.plot(datosfinales08_3[1,:,7],datosfinales08_3[1,:,8],c = "blue",marker='o')
ax.plot(datosfinales08_3[2,:,7],datosfinales08_3[2,:,8],c = "red",marker='o')
ax.plot(datosfinales08_3[5,:,7],datosfinales08_3[5,:,8],c = "green",marker='o')
ax.plot(datosfinales08_3[8,:,7],datosfinales08_3[8,:,8],c = "yellow",marker='o')
ax.plot(datosfinales08_3[9,:,7],datosfinales08_3[9,:,8],c = "brown",marker='o')
ax.plot(datosfinales08_3[10,:,7],datosfinales08_3[10,:,8],c = "cyan",marker='o')
#ax.axvline(x=b00, ymin=0., ymax=1,color='black')
#ax.axvline(x=b0, ymin=0., ymax=1,color='blue')
#ax.axvline(x=b0_m, ymin=0., ymax=1,color='red')
#ax.axvline(x=b0_m2, ymin=0., ymax=1,color='green')
#ax.axvline(x=b0_m3, ymin=0., ymax=1,color='yellow')
#ax.axvline(x=b0_m4, ymin=0., ymax=1,color='brown')
#ax.axvline(x=b0_m5, ymin=0., ymax=1,color='cyan')
ax.scatter(datosfinales08_3[0,61,7],datosfinales08_3[0,61,8],marker='s',c= "black",s=100)
ax.scatter(datosfinales08_3[1,69,7],datosfinales08_3[1,69,8],marker='s',c="blue",s=100)
ax.scatter(datosfinales08_3[2,74,7],datosfinales08_3[2,74,8],marker='s',c= "red",s=100)
ax.scatter(datosfinales08_3[5,67,7],datosfinales08_3[5,67,8],marker='s',c= "green",s=100)
ax.scatter(datosfinales08_3[8,53,7],datosfinales08_3[8,53,8],marker='s',c="yellow",s=100)
ax.scatter(datosfinales08_3[9,36,7],datosfinales08_3[9,36,8],marker='s',c="brown",s=100)
ax.scatter(datosfinales08_3[10,12,7],datosfinales08_3[10,12,8],marker='s',c="cyan",s=100)

ax.legend([    '$\sigma=0.000$','$\sigma=0.025$', 
            '$\sigma=0.100$', '$\sigma=0.500$',
            '$\sigma=0.800$', '$\sigma=1.000$',
            '$\sigma=1.200$', 
           '($\\beta_T=0.49$, $\\sigma_T=0.000$)','($\\beta_T=0.49$, $\\sigma_T=0.025$)',
           '($\\beta_T=0.48$, $\\sigma_T=0.100$)','($\\beta_T=0.41$, $\\sigma_T=0.500$)',
            '($\\beta_T=0.29$, $\\sigma_T=0.800$)','($\\beta_T=0.17$, $\\sigma_T=1.000$)',
          '($\\beta_T=0.04$, $\\sigma_T=1.200$)'], bbox_to_anchor = (1.3, 0.75))

#plt.text(.1,.794,'a=0.8')
ax.set_xlabel('$\hat{\\beta}_d$   $(days^{-1})$')
ax.set_ylabel('$\hat{\\alpha}_d$  $(days^{-1})$')
ax.set_xlim(0,0.6)
#ax.set_ylim(0.4,1.2)
ax.set_ylim(0.4,0.85)
# Out:
# (0.4, 0.85)

# %%
fig.savefig('F6_C_Vobs1F.jpg')

# %%
# Figura 6D
## Vobs=0.5

# %%
a=0.8
Vobs=0.49
V0=0.5
s=0
b00=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim_0=',b00)
s=0.025
b0=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0)
print('s_max=',np.sqrt(1.6))
s=0.1
b0_m=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim_r=',b0_m)
s=0.5
b0_m2=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m2)
s=1.
b0_m3=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m3)
s=1.1
b0_m4=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m4)
s=1.2
b0_m5=(a-(s**2)/2)/np.log(V0/Vobs)
print('beta_lim=',b0_m5)
# Out:
# beta_lim_0= 39.59865316200729
# beta_lim= 39.58318493811587
# s_max= 1.2649110640673518
# beta_lim_r= 39.35116157974474
# beta_lim= 33.41136360544365
# beta_lim= 14.849494935752734
# beta_lim= 9.652171708239273
# beta_lim= 3.9598653162007316

# %%
fig,ax=plt.subplots()
ax.plot(datosfinales08_4[0,:,7],datosfinales08_4[0,:,8], c="black",marker='o')
ax.plot(datosfinales08_4[1,:,7],datosfinales08_4[1,:,8],c = "blue",marker='o')
ax.plot(datosfinales08_4[2,:,7],datosfinales08_4[2,:,8],c = "red",marker='o')
ax.plot(datosfinales08_4[5,:,7],datosfinales08_4[5,:,8],c = "green",marker='o')
ax.plot(datosfinales08_4[8,:,7],datosfinales08_4[8,:,8],c = "yellow",marker='o')
ax.plot(datosfinales08_4[9,:,7],datosfinales08_4[9,:,8],c = "brown",marker='o')
ax.plot(datosfinales08_4[10,:,7],datosfinales08_4[10,:,8],c = "cyan",marker='o')

#ax.legend([    '$\sigma=0.000$','$\sigma=0.025$', 
#            '$\sigma=0.100$', '$\sigma=0.500$',
#            '$\sigma=0.800$', '$\sigma=1.000$',
#            '$\sigma=1.200$'], bbox_to_anchor = (1.3, 0.75))
#plt.title('$\\alpha=0.8(days^{-1})$, $V_{obs}=0.1 (cm^3)$, $V_0=0.5 (cm^3)$')
#plt.text(.1,.794,'a=0.8')
ax.set_xlabel('$\hat{\\beta}_d$   $(days^{-1})$')
ax.set_ylabel('$\hat{\\alpha}_d$  $(days^{-1})$')
ax.set_xlim(0,0.6)
ax.set_ylim(0.4,0.85)
# Out:
# (0.4, 0.85)

# %%
fig.savefig('F6_D_Vobs5F.jpg')

# %%
# para la tabla
a_g=0.8
b_g=0.17
nobs=0.5
sig=1.2
Vinf=nobs*np.exp((a_g-(sig**2)/2)/b_g)
print(Vinf)
# Out:
# 0.8004678215710422
